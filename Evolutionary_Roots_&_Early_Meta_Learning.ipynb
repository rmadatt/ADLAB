# %% [markdown]
# <a href="https://colab.research.google.com/github/rmadatt/ADLAB/blob/main/Evolutionary_Roots_%26_Early_Meta_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import plotly.express as px

# Data structure capturing the evolutionary epochs, topics, years, and scope
data = [
    # Category: Evolutionary Roots & Early Meta-Learning
    {
        "Category": "Early Foundations (1980s)",
        "Topic": "Meta Evolution & PSALMs",
        "Year": 1987,
        "Value": 25,
        "Description": "First genetic programming for universal programs of unlimited size applied to itself; PSALMs for meta-reinforcement learning.",
    },
    {
        "Category": "Early Foundations (1980s)",
        "Topic": "Artificial Curiosity & Intrinsic Motivation",
        "Year": 1990,
        "Value": 20,
        "Description": "Active agents driven by curiosity and intrinsic motivation to explore unmapped states.",
    },

    # Category: Neural & Reinforcement Learning RSI
    {
        "Category": "Neural & RL Frameworks (1990s)",
        "Topic": "Gradient-Based Fast Weight Programmers",
        "Year": 1991,
        "Value": 30,
        "Description": "End-to-end differentiable neural systems where slow networks control fast networks (precursor to modern linear transformers).",
    },
    {
        "Category": "Neural & RL Frameworks (1990s)",
        "Topic": "Self-Referential RNNs & Weight Inspection",
        "Year": 1992,
        "Value": 25,
        "Description": "Recurrent neural networks running and inspecting their own weight change and learning algorithms.",
    },
    {
        "Category": "Neural & RL Frameworks (1990s)",
        "Topic": "Meta-RL with Self-Modifying Policies",
        "Year": 1994,
        "Value": 30,
        "Description": "Lifelong reinforcement learning driven by self-modifying probability distributions and the Success-Story Algorithm.",
    },

    # Category: Optimality & Curriculum Search (2000s)
    {
        "Category": "Optimality & Search (2000s)",
        "Topic": "Asymptotically Optimal Curriculum Learning (OOPS)",
        "Year": 2002,
        "Value": 35,
        "Description": "Optimal Ordered Problem Solver efficiently searching program spaces to reuse and build upon prior code.",
    },
    {
        "Category": "Optimality & Search (2000s)",
        "Topic": "The Self-Improving Gödel Machine",
        "Year": 2003,
        "Value": 40,
        "Description": "Provably optimal universal RSI machine that rewrites its code only when a formal proof guarantees utility improvement.",
    },

    # Category: Modern Research & Scaling (2020s)
    {
        "Category": "Modern Scaled RSI (2020s)",
        "Topic": "Practical Software RSI & Large-Scale Meta-Learning",
        "Year": 2020,
        "Value": 45,
        "Description": "Cheap compute unlocks large-scale software-based meta-learning and commercial algorithmic self-improvement frameworks.",
    },
    {
        "Category": "Modern Scaled RSI (2020s)",
        "Topic": "Physical & Hardware-Level RSI",
        "Year": 2026,
        "Value": 50,
        "Description": "Extension from self-improving software to self-improving robotic hardware operating autonomously in the physical world.",
    },
]

df = pd.DataFrame(data)

# Create a hierarchical path for the treemap: Category -> Topic
fig = px.treemap(
    df,
    path=["Category", "Topic"],
    values="Value",
    custom_data=["Year", "Description"],
    title="<b>Evolution of Recursive Self-Improvement (RSI) & Meta-Learning</b>",
)

# Customize hover template to show Year and Description clearly
fig.update_traces(
    hovertemplate="<b>%{label}</b><br>Category: %{parent}<br>Year Introduced: %{customdata[0]}<br>Details: %{customdata[1]}<extra></extra>"
)

fig.update_layout(margin=dict(t=50, l=25, r=25, b=25), width=900, height=600)

# Display the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
